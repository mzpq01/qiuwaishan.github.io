# %%
# Import some libraries
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Import Seaborn
import seaborn as sns
# This allows plots to appear on the IPython notebook.
# %matplotlib inline

# %%
df = pd.read_csv("data/riyadh_route_edges_am.txt", sep=" ", index_col=0)
##df["travel_time"].head(2)
df.head(1)
# Out:
#      source  target  volume  capacity       voc  degree  free_travel_time  \
# eid
# 101       1       2  67.222      2850  0.023587     158          0.268594
#
#      travel_time
# eid
# 101     0.268594

# %%
# Let's define an empty undirected graph "RG".
RG = nx.Graph()
# We also define the values dictionary for the "edge attributes"
keys = ['volume', 'capacity', 'voc', 'degree', 'free_travel_time', 'travel_time']
for row in df.itertuples(index=False):    
    values = row[2:]    
    # We create a dictionary "edge_attributes" with the keys and row values
    edge_attributes = dict(zip(keys, values))    
    my_tuple = (row[0], row[1])   
    # We add the edge to the graph use "add_edge" function
    RG.add_edge(*my_tuple, attr_dict=edge_attributes)

# %%
# ******How to call nodes, edges, and their attributes******************************************
print "*1. "+str(RG.edges(1))     # call all edges starting from node_1
print "*2. "+str(RG.nodes()[:3])  # call first 3 nodes 
print "*3. "+str(RG.edges()[:5]) + "**" + str(RG.edges()[3:5])
print "*4. "+str(RG[1][2])   # call edge (1,2)
print "*5. "+str(RG[1][2]["travel_time"]) +" "+ str(RG[2][1]["travel_time"]) # call edge (1,2) attribute "travel_time"
print "*6. "+str(RG.node[1]) # call node_1 attributes
# Out:
# *1. [(1, 2), (1, 5748), (1, 9437)]
# *2. [1, 2, 3]
# *3. [(1, 2), (1, 5748), (1, 9437), (2, 7438), (2, 9950)]**[(2, 7438), (2, 9950)]
# *4. {'capacity': 2850, 'degree': 369, 'voc': 0.073342999999999992, 'volume': 209.02700000000002, 'travel_time': 0.268596, 'free_travel_time': 0.268594}
# *5. 0.268596 0.268596
# *6. {}

# %%
# Read dataframe of node with coordinates
nodes_df = pd.read_csv("data/riyadh_nodes.txt", sep=" ", index_col=0)
nodes_df.head(1)
# Out:
#          st_x       st_y
# id
# 1   46.849302  24.701475

# %%
for node_id in RG.nodes():
    ##df.loc[row_indexer,column_indexer]; df.loc[x,y] is a locator look for certain row x and column y
    ##loc_dict[node_id] = (float(nodes_df.loc[[node_id]]['st_x']), float(nodes_df.loc[[node_id]]['st_y']))
    # or the other way round, just simply call the dataframe by column name and row number
    RG.node[node_id]["coordinate"] = (nodes_df['st_x'][node_id], nodes_df['st_y'][node_id])

print RG.node[1]                # call attribute dictionary of node_1
print RG.node[1]["coordinate"]  # call value of key coordinate of node_1
# Out:
# {'coordinate': (46.849302248324101, 24.701475446932697)}
# (46.849302248324101, 24.701475446932697)

# %%
fsq_nodes = pd.read_csv('data/FoursqureCheckinNodes.csv', sep=",")
print fsq_nodes["NAME"][:3]
print fsq_nodes["NAME"][0]
ID = fsq_nodes['ID']
NAME = fsq_nodes['NAME']
CATEGORY = fsq_nodes['CATEGORY']
CHECKIN = fsq_nodes['CHECK-IN']
LAT = fsq_nodes['LAT']
LONG = fsq_nodes['LONG']
print len(ID), len(LAT)
fsq_nodes.head(1)
# Out:
# 0      Kingdom Centre | �Ŀ��ۿ_ �_�ܪĪĪܪۿ�
# 1                    Centria | �_��鿱�_�_
# 2    Panorama Mall | ��_��_���_�Ŀ_ �Ī_��
# Name: NAME, dtype: object
# Kingdom Centre | �Ŀ��ۿ_ �_�ܪĪĪܪۿ�
# 448 448
#                          ID                               NAME     CATEGORY  \
# 0  4bb78b8f3db7b7139222209a  Kingdom Centre | �Ŀ��ۿ_ �_�ܪĪĪܪۿ�  Coffee Shop
#
#    CHECK-IN        LAT       LONG
# 0     93420  24.711633  46.674771

# %%
# Now we build a Graph "fsq_G" to store the checkin points for foursqure
FSQ = nx.Graph()
coordinate_fsq = []
# We also define the values dictionary for the "node attributes"
for i in range(len(ID)):
        coordinate_fsq.append((LONG[i], LAT[i]))
        FSQ.add_node(i, fsq_id = ID[i],
                       coordinate = ((LONG[i], LAT[i])), checkin = CHECKIN[i], name = NAME[i], category = CATEGORY[i])
# Now we build a new dictionary dict_checkin to sort maximum checkin point
dict_checkin = {}
for i in FSQ.nodes():
    dict_checkin[i] = FSQ.node[i]["checkin"]
    
import operator
sorted_checkin = sorted(dict_checkin.items(), key = operator.itemgetter(1))
sorted_checkin.reverse()
MAX=[]
for i in range(10): # **Here we define the first X maximum checkin nodes to use**
    MAX.append(FSQ.node[sorted_checkin[i][0]]) # Maximum checkin node
print MAX
print "\n"
# Out:
# [{'coordinate': (46.674771309999997, 24.711632550000001), 'category': 'Coffee Shop', 'checkin': 93420, 'fsq_id': '4bb78b8f3db7b7139222209a', 'name': 'Kingdom Centre | \xaa\xc4\xbf\xb1\xaa\xdb\xbf_ \xbf_\xaa\xdc\xaa\xc4\xaa\xc4\xaa\xdc\xaa\xdb\xbf\xa9'}, {'coordinate': (46.683923010000001, 24.697129180000001), 'category': 'Coffee Shop', 'checkin': 73327, 'fsq_id': '4c892e4897828cfa5630a2aa', 'name': 'Centria | \xbf_\xaa\xe6\xbf\xe9\xbf\xb1\xaa_\xbf_'}, {'coordinate': (46.670182740000001, 24.69228232), 'category': 'Mall', 'checkin': 61518, 'fsq_id': '4eaac9cecc217eb08e78c735', 'name': 'Panorama Mall | \xbf\xe5\xbf_\xaa\xe6\xaa_\xbf\xb1\xbf_\xaa\xc4\xbf_ \xaa\xc4\xaa_\xaa\xdc'}, {'coordinate': (46.691358790000002, 24.699866279999998), 'category': 'Restaurant', 'checkin': 46252, 'fsq_id': '4bcc31a7b6c49c74e64b9391', 'name': 'Tao | \xbf\xe9\xbf_\xaa_'}, {'coordinate': (46.7307682, 24.780866289999999), 'category': 'Restaurant', 'checkin': 43501, 'fsq_id': '50ae0262e4b042e77fd721ab', 'name': 'Granada Center | \xaa\xc4\xbf\xb1\xaa\xdb\xbf_ \xbf_\xbf\xb1\xaa\xe6\xbf_\xbf\xe0\xbf\xa9'}, {'coordinate': (46.658296960000001, 24.74361948), 'category': 'Shop', 'checkin': 42949, 'fsq_id': '4d6174ab73e76a311d0ce196', 'name': 'Riyadh Gallery | \xbf_\xaa\xdc\xbf\xb1\xaa_\xbf_\xbf_ \xbf\x8c\xbf_\xaa\xdc\xaa_\xbf\xb1\xaa_'}, {'coordinate': (46.673643869999999, 24.693098469999999), 'category': 'Restaurant', 'checkin': 35804, 'fsq_id': '4b838dfcf964a520950931e3', 'name': 'Tutti Caf\x92\xe5 | \xbf\xa3\xaa\xe6\xaa_\xbf_\xbf_ \xbf_\xaa\xdc\xaa\xe4\xaa\xf6\xaa_\xbf\xa9'}, {'coordinate': (46.679921149999998, 24.74293381), 'category': 'Trail', 'checkin': 33564, 'fsq_id': '5193a1ad498eb76c92f3fb9d', 'name': 'Hayat Mall | \xbf_\xaa_\xbf_\xbf\xa9 \xaa\xc4\xaa_\xaa\xdc'}, {'coordinate': (46.697108749999998, 24.741082460000001), 'category': 'Mobile Phone Shop', 'checkin': 32294, 'fsq_id': '4cc3237ab2beb1f7d99e144c', 'name': 'King Abdullah Road Walking Area | \xaa\xc4\xaa\xc4\xbf\x82\xaa_ \xbf\xe0\xbf\xb1\xaa_\xaa\xe4 \xbf_\xaa\xdc\xaa\xc4\xaa\xdc\xaa\xdb \xbf_\xbf\xe5\xbf\xc0\xbf_\xaa\xdc\xaa\xdc\xaa\xf6'}, {'coordinate': (46.685976680000003, 24.68958374), 'category': 'Shoe Store', 'checkin': 31693, 'fsq_id': '4f41391be4b0f7b459efed08', 'name': 'Al-Faisaliyah Mall | \xaa\xc4\xbf\x8c\xaa\xc4\xbf_ \xbf_\xaa\xdc\xaa\x81\xaa_\xbf\xb5\xaa\xdc\xaa_\xbf\xa9'}]

# %%
# ******Now we found the nearest nodes to the maximun checkin nodes
start_list = []
for i in MAX:
    #print i['coordinate']
    dist_fsq = {}
    for node_id in RG.nodes():
        dist_fsq[node_id] = round(abs(i['coordinate'][0] -RG.node[node_id]["coordinate"][0])
        +abs(i['coordinate'][1] -RG.node[node_id]["coordinate"][1]),6)
    tmp_sort= sorted(dist_fsq.items(), key = operator.itemgetter(1))
    start_list.append(tmp_sort[0][0])
print "starting nodes are: " + str(start_list)
# Out:
# starting nodes are: [7601, 5808, 4590, 8716, 8960, 1274, 7546, 10084, 1062, 746]

# %%
import matplotlib.cm as cm # import the colormap library

fsq_sizes = [FSQ.node[u]["checkin"]*0.002 for u in FSQ.nodes()]
# plt.cm.coolwarm() is a function change value to color from cool-warm
fsq_colors = plt.cm.coolwarm(np.log(np.log(fsq_sizes)))

loc_fsq = {}
for node_index in FSQ.nodes():
    ##print node_index
    loc_fsq[node_index] = FSQ.node[node_index]["coordinate"]
    
plt.figure(figsize=(3,3))
nx.draw(FSQ, pos=loc_fsq, node_size=fsq_sizes, node_color=fsq_colors);
##nx.draw_networkx_labels(RG, pos=loc_dict); # semicolon suppresses output

# %%
# *******Now we caculate the Manhattan District Algorithm**********************************
import operator
start_node = [7601]
distance = {}
for i in start_node:
    for node_id in RG.nodes():
        distance[node_id] = round(abs(RG.node[i]["coordinate"][0] -RG.node[node_id]["coordinate"][0])
        +abs(RG.node[i]["coordinate"][1] -RG.node[node_id]["coordinate"][1]),6)
#print distance

# *******Now we sort the distance by Manhattan District algorithm, and have a sorted list "end_list"
sorted_distance = sorted(distance.items(), key = operator.itemgetter(1))
#print sorted_distance[:5]
#print sorted_distance[2][0]
end_list = []
for i in sorted_distance:
    end_list.append(i[0])
print len(end_list)
# Out:
# 10728

# %%
# Analysis the degrees, and centrality use "nx.degree()" and "nx.degree_centrality" function        
degrees = nx.degree(RG)
centralities= nx.degree_centrality(RG)
# degrees, centralities are dictionary, we need to call their all values as new lists
node_centrality=[round((centralities[u]*10000),2) for u in centralities]
node_degree = [i for i in degrees.values()]

#print node_centrality
#print node_degree
print "Done with process"
# Out:
# Done with process

# %%
# ****Right way to call edge, node attributes as visualization reference****
# colors = [G[u][v]['color'] for u,v in edges]
# weights = [G[u][v]['weight'] for u,v in edges]
# nx.draw(G, pos, edges=edges, edge_color=colors, width=weights)

import matplotlib.cm as cm # import the colormap library

node_colors = range(len(RG.nodes())) # plt.cm.coolwarm() is a function change value to color from cool-warm
node_sizes = node_centrality
edges = RG.edges()
weights = [RG[u][v]["volume"]*0.0009 for u,v in edges]
edge_colors = plt.cm.coolwarm(np.log(np.log(weights)))

loc_dict = {}
for node_index in RG.nodes():
    ##print node_index
    loc_dict[node_index] = RG.node[node_index]["coordinate"]

# %%
# If I pick any two intersections, is it possible to find a route
# between them? Check if the network is connected.
print "*Is the road network connected? "+ str(nx.is_connected(RG))
# Out:
# *Is the road network connected? True

# %%
# use nx.dijkstra_path(G,node_start,node_end, weight) to caculate shortest paths
import json
for start in start_node:
    ##print "*1. Start Node: " + str(start) 
    path_dict = {start:[]}
    for end in end_list[:5000]:  # [:x] control how many nodes in loop as end_point
        try:
            short_path = nx.dijkstra_path(RG, start, end, weight='travel_time')
            path_dict[start].append({end:short_path})
            ##print "*1.1 [start, End]: " + str([start, end])
            ##print "*1.2 Shortest path is: "+str(short_path)
            ##print "*1.3 Record dictionary is: "+str(path_dict)
            ##print "\n"
        except:
            pass
    ##print path_dict
    with open("Json/"+str(start)+".txt", "w") as text_file:
        text_file.write(json.dumps(path_dict))
        print "Done writting with Start Node: " + str(start) + "\n"

#print path_dict
# Out:
# Done writting with Start Node: 7601

# %%
# Let's define a new empty undirected graph "Shortest_RG".
Shortest_RG = nx.Graph()

sum_time = {}
tmp_edges = []

for i in start_node:
    for j in range(len(path_dict[i])):        
        tmp_dict= path_dict[i][j]
        tmp= tmp_dict.values()
        tmp_list= tmp[0]
        #print "1* i="+str(i) + ", j="+str(j)+ ", "+str(tmp_dict)+", list length="+str(len(tmp_list))        
        time_list = []
        if len(tmp_list) > 1:
            for x in range(len(tmp_list)-1):
                o_id = tmp_list[x]
                d_id = tmp_list[x+1]
                ##print o_id, d_id                    
                time_list.append(round(RG[o_id][d_id]["travel_time"],2))                                
                tmp_sum = round(sum(time_list),2)
                if tmp_sum < 10: ##############################
                    sum_time[(o_id,d_id)] = tmp_sum
                    new_edge_attr = RG[o_id][d_id]
                    ##print new_edge_attr
                    Shortest_RG.add_edge(*(o_id,d_id), attr_dict= new_edge_attr)
                    Shortest_RG[o_id][d_id]["sum_time"]= round(sum(time_list),2)
                    ##print "2* time_list= " +str(time_list)
                    ##print "3* sum_time= " +str(sum_time)
        ##print "\n"
print "Done with Caculation"
# Out:
# Done with Caculation

# %%
# Now we can add node coordinates
loc_dict_sh = {}
for node_index in Shortest_RG.nodes():
    ##print node_index
    loc_dict_sh[node_index] = RG.node[node_index]["coordinate"]
    Shortest_RG.node[node_index]["coordinate"] = RG.node[node_index]["coordinate"]
    ##print loc_dict[node_index]

# %%
degrees_sh = nx.degree(Shortest_RG)
node_sizes_sh = []
for i in Shortest_RG.nodes():
    node_sizes_sh.append(degrees_sh[i])

node_colors_sh = range(len(Shortest_RG.nodes()))

edges_sh = Shortest_RG.edges()
weights_sh = [15/Shortest_RG[u][v]["sum_time"] for u,v in edges_sh]
weights_sh_2 = [u+0.5 for u in weights_sh]
#edge_colors = [Shortest_RG[u][v]["volume"] for u,v in edges]
edge_colors_sh = plt.cm.coolwarm(np.log(weights_sh))

##print node_sizes
##print node_colors
##print edges
##print weights
##print edge_colors

plt.figure(figsize=(40,40))
#nx.draw(FSQ, pos=loc_fsq, node_size=fsq_sizes, node_color=fsq_colors);
nx.draw(RG, pos=loc_dict, node_size=0.1, width=0.3, node_color=node_colors, edge_color = "#e8d7dd");
nx.draw(Shortest_RG, pos=loc_dict_sh, 
        node_size=0.2, node_color=node_colors_sh, width=weights_sh_2, edge_color=edge_colors_sh);
#nx.draw_networkx_labels(Shortest_RG,pos=loc_dict); # semicolon suppresses output

# %%
print Shortest_RG.edge[8193][3488]
print Shortest_RG.edge[3488][8193]
print Shortest_RG.edges()[:3]
print Shortest_RG.node[8193]
# Out:
# {'volume': 149.60499999999999, 'travel_time': 0.079040600000000003, 'capacity': 950, 'degree': 285, 'voc': 0.15747900000000001, 'sum_time': 9.81, 'free_travel_time': 0.079033300000000015}
# {'volume': 149.60499999999999, 'travel_time': 0.079040600000000003, 'capacity': 950, 'degree': 285, 'voc': 0.15747900000000001, 'sum_time': 9.81, 'free_travel_time': 0.079033300000000015}
# [(8193, 3488), (8195, 3731), (8195, 6670)]
# {'coordinate': (46.751305196579295, 24.700087105217399)}

# %%
# Now construct the multi-tier dictionary structures.
# Build the 1st tier dictionary, called \"geoDataSet\".\n",
geoDataSet  = {}
geoDataSet["type"] = "FeatureCollection"
geoDataSet["features"] = []

for i in Shortest_RG.edges()[:10]:   
    id_o = i[0]
    id_d = i[1]
    tmp_dict = {}
    tmp_dict["type"] = "Feature"
    tmp_dict["properties"]= Shortest_RG.edge[id_o][id_d]
    tmp_dict["geometry"] = {}
    tmp_dict["geometry"]["type"] = "LineString"
    tmp_x1 = Shortest_RG.node[id_o]['coordinate'][0]
    tmp_y1 = Shortest_RG.node[id_o]['coordinate'][1]
    tmp_x2 = Shortest_RG.node[id_d]['coordinate'][0]
    tmp_y2 = Shortest_RG.node[id_d]['coordinate'][1]
    tmp_dict["geometry"]["coordinates"] = [[tmp_x1,tmp_y1],[tmp_x2,tmp_y2]]                  
    geoDataSet["features"].append(tmp_dict)

print geoDataSet

with open("Json/"+str(start_node[0])+".json", "w") as text_file:
    text_file.write(json.dumps(geoDataSet))
    print "Done writting with Start Node: " + str(start) + "\n"
# Out:
# {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'LineString', 'coordinates': [[46.751305196579295, 24.700087105217399], [46.7518325171173, 24.700162208476602]]}, 'type': 'Feature', 'properties': {'volume': 149.60499999999999, 'travel_time': 0.079040600000000003, 'capacity': 950, 'degree': 285, 'voc': 0.15747900000000001, 'sum_time': 9.81, 'free_travel_time': 0.079033300000000015}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.703218260387494, 24.682855968609299], [46.703199191117001, 24.6827252658925]]}, 'type': 'Feature', 'properties': {'capacity': 1900, 'degree': 1025, 'voc': 1.11605, 'sum_time': 4.99, 'volume': 2120.5, 'travel_time': 0.015215299999999999, 'free_travel_time': 0.0123429}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.703218260387494, 24.682855968609299], [46.703233072547903, 24.682946089567601]]}, 'type': 'Feature', 'properties': {'capacity': 1900, 'degree': 1028, 'voc': 1.14384, 'sum_time': 4.97, 'volume': 2173.29, 'travel_time': 0.0124785, 'free_travel_time': 0.0099289900000000004}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.631413948475199, 24.798166581948198]]}, 'type': 'Feature', 'properties': {'capacity': 6963, 'degree': 857, 'voc': 0.34728000000000003, 'sum_time': 7.78, 'volume': 2418.1100000000001, 'travel_time': 0.026184100000000002, 'free_travel_time': 0.026127099999999997}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.632125621034497, 24.798601240897497]]}, 'type': 'Feature', 'properties': {'capacity': 6963, 'degree': 956, 'voc': 0.381212, 'sum_time': 7.78, 'volume': 2654.3800000000001, 'travel_time': 0.025396000000000002, 'free_travel_time': 0.025315799999999999}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.631354510193006, 24.798584820669301]]}, 'type': 'Feature', 'properties': {'capacity': 1900, 'degree': 300, 'voc': 0.18632699999999999, 'sum_time': 7.79, 'volume': 354.02099999999996, 'travel_time': 0.041016299999999999, 'free_travel_time': 0.041008900000000001}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.631348051013404, 24.798280162779001]]}, 'type': 'Feature', 'properties': {'capacity': 6963, 'degree': 883, 'voc': 0.33649600000000002, 'sum_time': 7.78, 'volume': 2343.02, 'travel_time': 0.026820999999999998, 'free_travel_time': 0.026769499999999998}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.632183012089101, 24.798499038774199]]}, 'type': 'Feature', 'properties': {'capacity': 6963, 'degree': 858, 'voc': 0.19850000000000001, 'sum_time': 7.78, 'volume': 1382.1600000000001, 'travel_time': 0.025439, 'free_travel_time': 0.025433000000000001}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.631645790250801, 24.797978959689196]]}, 'type': 'Feature', 'properties': {'capacity': 1900, 'degree': 871, 'voc': 1.1354, 'sum_time': 7.75, 'volume': 2157.2600000000002, 'travel_time': 0.049200400000000005, 'free_travel_time': 0.039383000000000001}}, {'geometry': {'type': 'LineString', 'coordinates': [[46.631779644388196, 24.798381547100398], [46.631924625498797, 24.798784012975602]]}, 'type': 'Feature', 'properties': {'capacity': 1900, 'degree': 207, 'voc': 0.22879899999999997, 'sum_time': 7.79, 'volume': 434.71899999999999, 'travel_time': 0.039675000000000002, 'free_travel_time': 0.039658699999999998}}]}
# Done writting with Start Node: 7601
